# %%
#First Forum Task
def average(numbers):
    total=float(sum(numbers))
    return (total/len(numbers))

def get_average(student):
    homework_average=average(student["homework"])
    quizzes_average=average(student["quizzes"])
    tests_average=average(student["tests"])

    homework_average=homework_average*0.1
    quizzes_average=quizzes_average*0.3
    tests_average=tests_average*0.6
    return(homework_average+quizzes_average+tests_average)

def get_letter_score(score):
    if score>=90:
        return 'A'
    elif score>=80:
        return 'B'
    elif score>=70:
        return 'C'
    elif score>=60:
        return 'D'
    else:
        return 'F'
    
def get_class_average(students):
    results=[]
    for student in students:
        student_average=get_average(student)
        results.append(student_average)
    return average(results)

#The students' dictionary
lloyd = {
 "name": "Lloyd",
 "homework": [90.0,97.0,75.0,92.0],
 "quizzes": [88.0,40.0,94.0],
 "tests": [75.0,90.0]
}
alice = {
 "name": "Alice",
 "homework": [100.0, 92.0, 98.0, 100.0],
 "quizzes": [82.0, 83.0, 91.0],
 "tests": [89.0, 97.0]
}
tyler = {
 "name": "Tyler",
 "homework": [0.0, 87.0, 75.0, 22.0],
 "quizzes": [0.0, 75.0, 78.0],
 "tests": [100.0, 100.0]
}

student_list=[lloyd,alice,tyler]

#display the dictionaries
for i in range (0,len(student_list)):
    for key,value in student_list[i].items():
        print (f"{key}: {value}")
    print('')

#call the get_average function and display the student's letter score
lloyd_average=get_average(lloyd)
print(f"Lloyd's letter score is {get_letter_score(lloyd_average)}")
alice_average=get_average(alice)
print(f"Alice's letter score is {get_letter_score(alice_average)}")
tyler_average=get_average(tyler)
print(f"Tyler's letter score is {get_letter_score(tyler_average)}")

#call the get_average function and display the class score
class_average=get_class_average(student_list)
print(f'The class average: {class_average:.3f}')
print(f'The letter score for the class: {get_letter_score(class_average)}')
# Out:
# name: Lloyd
# homework: [90.0, 97.0, 75.0, 92.0]
# quizzes: [88.0, 40.0, 94.0]
# tests: [75.0, 90.0]
#
# name: Alice
# homework: [100.0, 92.0, 98.0, 100.0]
# quizzes: [82.0, 83.0, 91.0]
# tests: [89.0, 97.0]
#
# name: Tyler
# homework: [0.0, 87.0, 75.0, 22.0]
# quizzes: [0.0, 75.0, 78.0]
# tests: [100.0, 100.0]
#
# Lloyd's letter score is B
# Alice's letter score is A
# Tyler's letter score is C
# The class average: 83.867
# The letter score for the class: B

# %%
#Second Forum Task

#importing sys to use the exit() function 
import sys 

course_tuple=('COP 2510','EGN 3000L','MAC 2281','MUH 3016','PHY 2048')
course_input=input("Enter a course number: ")

#validating the user's input
for i in course_tuple:
    if course_input not in course_tuple:
        print("Course number is invalid")
        sys.exit()

course_name={
        course_tuple[0]:"Programming Concept",
        course_tuple[1]: 'Foundations of Engineering Lab',
        course_tuple[2]: 'Calculus I',
        course_tuple[3]: 'Survey of Jazz',
        course_tuple[4]: 'General Physics I'
    }

course_instructor={
        course_tuple[0]:"Z. Beasley",
        course_tuple[1]: 'J. Anderson',
        course_tuple[2]: 'A. Makaryus',
        course_tuple[3]: 'A. Wilkins',
        course_tuple[4]: 'G. Pradhan'
    }

course_time={
        course_tuple[0]:"MW 12:30pm – 1:45pm",
        course_tuple[1]: 'TR 11:00am – 12:15pm',
        course_tuple[2]: 'MW 9:30am – 10:45am',
        course_tuple[3]: 'online asynchronous',
        course_tuple[4]: 'TR 5:00pm – 6:15pm'
    }

#searching the index of the user's input
for i in range(0, len(course_tuple)):
    if course_input==course_tuple[i]:
        course_index=i
        break

#display course name, course instructor, and course time
print("The course details are:")
print(f"Course name: {course_name[course_tuple[i]]}")
print(f"Course instructor: {course_instructor[course_tuple[i]]}")
print(f"Course time: {course_time[course_tuple[i]]}")
# Out:
# The course details are:
# Course name: Survey of Jazz
# Course instructor: A. Wilkins
# Course time: online asynchronous

# %%
#Third Forum Task

#function to calculate the total sales
def total(number):
    total_result=0
    for i in number:
        total_result+=i
    return total_result

week=("Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday")
sales=[]

#user's input and validating the input
for day in week:
    temp=eval(input(f"Enter the sales for {day}: "))
    while(temp<0):
        temp=eval(input(f"Input was invalid. Please re-enter the sales for {day}: "))
    sales.append(temp)

#calculate the total, minimum, and maximum sales based on the user's input
total_sales=total(sales)
min_sales=min(sales)
max_sales=max(sales)

#display the output
print(f"The total sales is ${total_sales:,.2f}")
print(f"The minimum sale amount was ${min_sales:,.2f}")
print(f"The maximum sale amount was ${max_sales:,.2f}")
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3526 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[21], line 15
#     temp=eval(input(f"Enter the sales for {day}: "))
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
#Fourth Forum Task

morse_code=(' ','--..--','.-.-.-','..--..','-----','.----',
            '..---','...--','....-','.....','-....','--...',
            '---..','----.','.-','-...','-.-.','-..','.','..-.',
            '--.','. ...','. .','.---','-.-','.-..','--','-.',
            '---','.---.','--.-','.-.','...','-','..-','...-',
            '.--','-..-','-.--','--..')

user_input=input("Enter a string: ")
user_input=user_input.upper()
user_input=tuple(user_input)

#display the morse code based on user input
for i in user_input:
    if i==' ':
        print(morse_code[0],end='')
    elif i==',':
        print(morse_code[1],end='')
    elif i=='.':
        print(morse_code[2],end='')
    elif i=='?':
        print(morse_code[3],end='')
    elif i=='0':
        print(morse_code[4],end='')
    elif i=='1':
        print(morse_code[5],end='')
    elif i=='2':
        print(morse_code[6],end='')
    elif i=='3':
        print(morse_code[7],end='')
    elif i=='4':
        print(morse_code[8],end='')
    elif i=='5':
        print(morse_code[9],end='')
    elif i=='6':
        print(morse_code[10],end='')
    elif i=='7':
        print(morse_code[11],end='')
    elif i=='8':
        print(morse_code[12],end='')
    elif i=='9':
        print(morse_code[13],end='')
    elif i=='A':
        print(morse_code[14],end='')
    elif i=='B':
        print(morse_code[15],end='')
    elif i=='C':
        print(morse_code[16],end='')
    elif i=='D':
        print(morse_code[17],end='')
    elif i=='E':
        print(morse_code[18],end='')
    elif i=='F':
        print(morse_code[19],end='')
    elif i=='G':
        print(morse_code[20],end='')
    elif i=='H':
        print(morse_code[21],end='')
    elif i=='I':
        print(morse_code[22],end='')
    elif i=='J':
        print(morse_code[23],end='')
    elif i=='K':
        print(morse_code[24],end='')
    elif i=='L':
        print(morse_code[25],end='')
    elif i=='M':
        print(morse_code[26],end='')
    elif i=='N':
        print(morse_code[27],end='')
    elif i=='O':
        print(morse_code[28],end='')
    elif i=='P':
        print(morse_code[29],end='')
    elif i=='Q':
        print(morse_code[30],end='')
    elif i=='R':
        print(morse_code[31],end='')
    elif i=='S':
        print(morse_code[32],end='')
    elif i=='T':
        print(morse_code[33],end='')
    elif i=='U':
        print(morse_code[34],end='')
    elif i=='V':
        print(morse_code[35],end='')
    elif i=='W':
        print(morse_code[36],end='')
    elif i=='X':
        print(morse_code[37],end='')
    elif i=='Y':
        print(morse_code[38],end='')
    elif i=='Z':
        print(morse_code[39],end='')
# Out:
# . .....-...-..---
